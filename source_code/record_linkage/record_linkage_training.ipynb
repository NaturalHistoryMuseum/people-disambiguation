# %%
import argparse
import numpy as np
import pandas as pd
import itertools
import os
import tqdm
import matplotlib.pyplot as plt
from collections import defaultdict
from sklearn.metrics import roc_auc_score
import gc
from thefuzz import fuzz
from thefuzz import process
import time
import re
import recordlinkage
from sklearn.model_selection import train_test_split

gc.collect()
# Out:
# 0

# %%
a = pd.read_csv('~/Downloads/a.csv',chunksize=10000,encoding='utf-8',on_bad_lines='skip',engine='python')
a = pd.concat(a)
a['wikiID'] = a['id']
a = a.set_index('id')
print(a.head())

b = pd.read_csv('~/Downloads/b.csv',chunksize=10000,encoding='utf-8',on_bad_lines='skip',engine='python')
b = pd.concat(b)
b['harvardIndex'] = b['id']
b = b.set_index('id')
print(b.head())
# Out:
#                               label  dateOfBirth  dateOfDeath  \
# id
# Q100142069             Frida Eggens          NaN          NaN
# Q100146795       Elizabeth Harrison       1792.0       1834.0
# Q100149196              Russell Cox          NaN          NaN
# Q100152296  Alda Pereira da Fonseca       1882.0          NaN
# Q100156193  Laurence Henry Millener       1914.0       2000.0
#
#            countryOfCitizenshipISO harvardIndex             bionomia  \
# id
# Q100142069                      SE          NaN                  NaN
# Q100146795                      GB          NaN           Q100146795
# Q100149196                     NaN          NaN  0000-0001-5149-1709
# Q100152296                      BR          NaN                  NaN
# Q100156193                      NZ          NaN           Q100156193
#
#            authorAbbrv                                            aliases  \
# id
# Q100142069      Eggens                                             Eggens
# Q100146795         NaN                     Mrs Arnold Harrison, Mrs A. H.
# Q100149196         NaN                                                NaN
# Q100152296         NaN                                                NaN
# Q100156193         NaN  L. H. Millener, Laurie Henry Millener, Laurie ...
#
#             firstName  lastName      wikiID
# id
# Q100142069      Frida    Eggens  Q100142069
# Q100146795  Elizabeth  Harrison  Q100146795
# Q100149196    Russell       Cox  Q100149196
# Q100152296       Alda   Fonseca  Q100152296
# Q100156193   Laurence  Millener  Q100156193
#       Standard/Label Name  birthYear  deathYear birthYearIsApprox  \
# id
# 89438          Shin. Sato        NaN        NaN               NaN
# 64680       E. J. Hoffman        NaN        NaN               NaN
# 34653     D. W. Stevenson     1942.0        NaN             False
# 42819  D. Müller-Doblies     1938.0        NaN             False
# 82862            Boutroux        NaN        NaN               NaN
#
#       geographyISO firstName middleName         lastName B & P Author Abbrev.  \
# id
# 89438           DE    Shinya        NaN             Sato           Shin. Sato
# 64680          NaN     Emily         J.          Hoffman        E. J. Hoffman
# 34653           US    Dennis    William        Stevenson          D. W. Stev.
# 42819           DE  Dietrich        NaN  Müller-Doblies    D. Müll.-Doblies
# 82862          NaN        A.        NaN         Boutroux             Boutroux
#
#                                                     Name  harvardIndex
# id
# 89438                          Sato, Shinya, Shinya Sato         89438
# 64680                Hoffman, Emily J., Emily J. Hoffman         64680
# 34653  Stevenson, Dennis William, Dennis William Stev...         34653
# 42819  Müller-Doblies, Dietrich, Dietrich Müller-Do...         42819
# 82862                          Boutroux, A., A. Boutroux         82862

# %%
# Find out the True Matches of dataframe A and dataframe B
a['harvardIndex'] = pd.to_numeric(a['harvardIndex'],errors='coerce') 
temp = pd.merge(a, b, how='inner', on=None, left_on='harvardIndex', right_on='harvardIndex',
                  left_index=False, right_index=False, sort=False,
                  suffixes=('_wiki', '_harvard'), copy=False, indicator=False)

print(temp.columns.to_list())
temp.head()
# Out:
# ['label', 'dateOfBirth', 'dateOfDeath', 'countryOfCitizenshipISO', 'harvardIndex', 'bionomia', 'authorAbbrv', 'aliases', 'firstName_wiki', 'lastName_wiki', 'wikiID', 'Standard/Label Name', 'birthYear', 'deathYear', 'birthYearIsApprox', 'geographyISO', 'firstName_harvard', 'middleName', 'lastName_harvard', 'B & P Author Abbrev.', 'Name']
#                        label  dateOfBirth  dateOfDeath  \
# 0             Johann Bartsch       1709.0       1738.0
# 1  Townshend Stith Brandegee       1843.0       1925.0
# 2          Cécile Kruyfhooft       1950.0          NaN
# 3            Charles Bullard       1869.0       1960.0
# 4               Zubair Aslam          NaN          NaN
#
#   countryOfCitizenshipISO  harvardIndex    bionomia authorAbbrv  \
# 0                      DE       27614.0         NaN     Bartsch
# 1                      US       17284.0    Q1002345   Brandegee
# 2                      BE       18988.0         NaN         NaN
# 3                      US        3553.0  Q100354624         NaN
# 4                     NaN       88384.0         NaN         NaN
#
#                                              aliases firstName_wiki  \
# 0         Johannes Bartsch, Joannes Bartsch, Bartsch         Johann
# 1  Brandegee, T. S. Brandegee, Townshend S. Brand...      Townshend
# 2                                                NaN         Cécile
# 3                                         C. Bullard        Charles
# 4                                                NaN         Zubair
#
#   lastName_wiki  ... Standard/Label Name birthYear  deathYear  \
# 0       Bartsch  ...          J. Bartsch    1709.0     1738.0
# 1     Brandegee  ...     T. S. Brandegee    1843.0     1925.0
# 2    Kruyfhooft  ...       C. Kruyfhooft    1950.0        NaN
# 3       Bullard  ...     Charles Bullard    1869.0        NaN
# 4         Aslam  ...            Z. Aslam       NaN        NaN
#
#    birthYearIsApprox geographyISO firstName_harvard middleName  \
# 0              False          NaN            Johann        NaN
# 1              False       MX, US         Townshend      Stith
# 2              False           BE            Cecile        NaN
# 3              False           US           Charles        NaN
# 4                NaN           KR            Zubair        NaN
#
#   lastName_harvard B & P Author Abbrev.  \
# 0          Bartsch              Bartsch
# 1        Brandegee            Brandegee
# 2       Kruyfhooft                  NaN
# 3          Bullard                  NaN
# 4            Aslam                Aslam
#
#                                                 Name
# 0                    Bartsch, Johann, Johann Bartsch
# 1  Brandegee, Townshend Stith, Townshend Stith Br...
# 2                                 Kruyfhooft, Cecile
# 3                                   Bullard, Charles
# 4                                      Aslam, Zubair
#
# [5 rows x 21 columns]

# %%
'''
use the pd.merge above to prepare training data -- find out the index true pairs
training = 0.75, testing = 0.25, no validat set

experiment setting
    - supervised: Logistics regression, navie bayes, SVM
    - undupervised: k-mean, ECM

refs
https://recordlinkage.readthedocs.io/en/latest/ref-classifiers.html
https://recordlinkage.readthedocs.io/en/latest/guides/classifiers.html#
'''

def define_true_pairs(indexList1, indexList2, indexName1, indexName2):
    arrays = [indexList1, indexList2]
    tuples = list(zip(*arrays))
    index = pd.MultiIndex.from_tuples(tuples, names=[indexName1, indexName2])
    return index

# %%
true_matches = define_true_pairs(temp['wikiID'],temp['harvardIndex'].astype(int),'wikiID','harvardIndex')
print('There is '+ str(len(true_matches)) +' HarvardIndex records in Wikidata that can find a match, which is ' + str(len(true_matches)/len(a)*100) +'%')
print('There is '+ str(len(true_matches)) +' HarvardIndex records can be found in Wikidata, which is ' + str(len(true_matches)/len(b)*100) +'%')
# Out:
# There is 31022 HarvardIndex records in Wikidata that can find a match, which is 43.09329332666555%
# There is 31022 HarvardIndex records can be found in Wikidata, which is 40.55375444467685%

# %%
print(true_matches)
# Out:
# MultiIndex([(   'Q100222', 27614),
#             (  'Q1002345', 17284),
#             ('Q100255559', 18988),
#             ('Q100354624',  3553),
#             ('Q100377900', 88384),
#             (   'Q100411', 23934),
#             ('Q100454982', 50126),
#             (   'Q100523', 78274),
#             ('Q100587885', 29015),
#             ('Q100587966', 14467),
#             ...
#             (    'Q65219', 25324),
#             (     'Q6527', 26300),
#             (    'Q65302',  4297),
#             (    'Q65400',  2192),
#             (    'Q65402', 46610),
#             (    'Q65451',  1041),
#             (    'Q65475', 38017),
#             (    'Q65505', 80335),
#             (     'Q6694',  1813),
#             (     'Q7324',  8283)],
#            names=['wikiID', 'harvardIndex'], length=31022)

# %%
# Find unmatched wiki_data entries
unmatched_wiki_data = a[~a.index.isin(true_matches.get_level_values('wikiID'))].reset_index()
unmatched_wiki_data
# Out:
#                id                       label  dateOfBirth  dateOfDeath  \
# 0      Q100142069                Frida Eggens          NaN          NaN
# 1      Q100146795          Elizabeth Harrison       1792.0       1834.0
# 2      Q100149196                 Russell Cox          NaN          NaN
# 3      Q100152296     Alda Pereira da Fonseca       1882.0          NaN
# 4      Q100156193     Laurence Henry Millener       1914.0       2000.0
# ...           ...                         ...          ...          ...
# 40961      Q65499  Wilhelm Ferdinand Erichson       1809.0       1848.0
# 40962       Q7450            Asima Chatterjee       1917.0       2006.0
# 40963        Q762           Leonardo da Vinci       1452.0       1519.0
# 40964       Q8619              Pierre Trudeau       1919.0       2000.0
# 40965        Q926              Roald Amundsen       1872.0       1928.0
#
#       countryOfCitizenshipISO  harvardIndex             bionomia authorAbbrv  \
# 0                          SE           NaN                  NaN      Eggens
# 1                          GB           NaN           Q100146795         NaN
# 2                         NaN           NaN  0000-0001-5149-1709         NaN
# 3                          BR           NaN                  NaN         NaN
# 4                          NZ           NaN           Q100156193         NaN
# ...                       ...           ...                  ...         ...
# 40961                      DE           NaN               Q65499         NaN
# 40962                      IN           NaN                  NaN         NaN
# 40963                     NaN           NaN                  NaN         NaN
# 40964                      CA           NaN                Q8619         NaN
# 40965                      NO           NaN                 Q926         NaN
#
#                                                  aliases  firstName  \
# 0                                                 Eggens      Frida
# 1                         Mrs Arnold Harrison, Mrs A. H.  Elizabeth
# 2                                                    NaN    Russell
# 3                                                    NaN       Alda
# 4      L. H. Millener, Laurie Henry Millener, Laurie ...   Laurence
# ...                                                  ...        ...
# 40961  Erichson, W. F. Erichson, Wilhelm F. Erichson,...    Wilhelm
# 40962                                Asima Chattopadhyay      Asima
# 40963  Leonardo di ser Piero da Vinci, Leonardo, da V...   Leonardo
# 40964  Pierre Elliott Trudeau, Joseph Philippe Pierre...     Pierre
# 40965     Roald Engelbregt Gravning Amundsen, R Amundsen      Roald
#
#          lastName      wikiID
# 0          Eggens  Q100142069
# 1        Harrison  Q100146795
# 2             Cox  Q100149196
# 3         Fonseca  Q100152296
# 4        Millener  Q100156193
# ...           ...         ...
# 40961    Erichson      Q65499
# 40962  Chatterjee       Q7450
# 40963       Vinci        Q762
# 40964     Trudeau       Q8619
# 40965    Amundsen        Q926
#
# [40966 rows x 12 columns]

# %%
# Find unmatched harvard_data entries
unmatched_harvard_data = b[~b.index.isin(true_matches.get_level_values('harvardIndex'))].reset_index()
unmatched_harvard_data
# Out:
#           id      Standard/Label Name  birthYear  deathYear birthYearIsApprox  \
# 0      89438               Shin. Sato        NaN        NaN               NaN
# 1      37972         J. T. I. Boswell     1822.0        NaN             False
# 2      86767  H. H. Hu & W. C. Chêng        NaN        NaN               NaN
# 3      29813              P. Lasquety        NaN        NaN               NaN
# 4      29336              J. I. Treby        NaN        NaN               NaN
# ...      ...                      ...        ...        ...               ...
# 45481  88336            Flora Altaica        NaN        NaN               NaN
# 45482  35178               J. Laycock        NaN        NaN               NaN
# 45483  29118                  Tutajev        NaN        NaN               NaN
# 45484  72000                    Boeuf        NaN        NaN               NaN
# 45485   7450         Colin C. Stewart     1873.0     1944.0             False
#
#       geographyISO firstName     middleName  lastName B & P Author Abbrev.  \
# 0               DE    Shinya            NaN      Sato           Shin. Sato
# 1              NaN      John  Thomas Irving   Boswell                  NaN
# 2               CN      Hsen   Hsu & Chêng        Hu     Hu & W. C. Cheng
# 3              NaN        P.            NaN  Lasquety                  NaN
# 4               RU       Ju.             I.     Treby                  NaN
# ...            ...       ...            ...       ...                  ...
# 45481           RU     Flora            NaN   Altaica                  NaN
# 45482          NaN      John            NaN   Laycock                  NaN
# 45483           RU   Tutajev            NaN       NaN                  NaN
# 45484       FR, TN        F.            NaN     Boeuf                Boeuf
# 45485           US     Colin             C.   Stewart                  NaN
#
#                                        Name  harvardIndex
# 0                 Sato, Shinya, Shinya Sato         89438
# 1               Boswell, John Thomas Irving         37972
# 2           Hu, Hsen Hsu & Chêng, Wan-chun         86767
# 3                              Lasquety, P.         29813
# 4                Treby, Ju. I., J. Treboux?         29336
# ...                                     ...           ...
# 45481                         Flora Altaica         88336
# 45482                         Laycock, John         35178
# 45483                               Tutajev         29118
# 45484                   Boeuf, F., F. Boeuf         72000
# 45485  Stewart, Colin C., C. C. Stewart bis          7450
#
# [45486 rows x 12 columns]

# %%
# Find non-matched pairs in dataframe a
non_matched_a = a[~a['harvardIndex'].isin(temp['harvardIndex']) & a['harvardIndex'].notna()]
    
# Find non-matched pairs in dataframe b
non_matched_b = b[~b['harvardIndex'].isin(temp['harvardIndex']) & b['harvardIndex'].notnull()]

# %%
print('Non-matched data where HarvardIndex is not null or NaN:')
print('\nNon-matched pairs in dataframe wiki:')
print(len(non_matched_a))

print('\nNon-matched pairs in dataframe havard:')
print(len(non_matched_b))
# Out:
# Non-matched data where HarvardIndex is not null or NaN:
#
# Non-matched pairs in dataframe wiki:
# 2389
#
# Non-matched pairs in dataframe havard:
# 45486

# %%
print('There is '+ str(len(non_matched_a)) +' HarvardIndex records in Wikidata which cannot be found in HarvardIndex, which is ' + str(len(non_matched_a)/len(a)*100) +'%')
print('There is '+ str(len(non_matched_b)) +' HarvardIndex records cannot find a match, which is ' + str(len(non_matched_b)/len(b)*100) +'%')
# Out:
# There is 2389 HarvardIndex records in Wikidata which cannot be found in HarvardIndex, which is 3.3186086569983884%
# There is 45486 HarvardIndex records cannot find a match, which is 59.4619326500732%

# %%
# Define the function to split the full name into first name and last name
def split_full_name(full_name):
    if pd.isnull(full_name) or full_name == '':
        return '', ''
    parts = full_name.split()
    first_name = ' '.join(parts[:-1])
    last_name = parts[-1]
    return first_name, last_name

# Define the function to convert each word in the first name to the desired format
def convert_to_initial(name):
    if pd.isnull(name) or name == '':
        return ''
    initials = [word[0].upper() + '.' for word in name.split()]
    return ' '.join(initials)

# %%
dfa = a.copy()
dfb = b.copy()

# %%
# Apply the split_full_name function to separate first name and last name
dfa[['first_name', 'last_name']] = dfa['label'].apply(lambda x: pd.Series(split_full_name(x)))

# Apply the convert_to_initial function to the first name column
dfa['first_name_initial'] = dfa['first_name'].apply(convert_to_initial)

# %%
# Apply the split_full_name function to separate first name and last name
dfb[['first_name', 'last_name']] = dfb['Standard/Label Name'].apply(lambda x: pd.Series(split_full_name(x)))

# Apply the convert_to_initial function to the first name column
dfb['first_name_initial'] = dfb['first_name'].apply(convert_to_initial)

# %%
dfa.head()
# Out:
#                               label  dateOfBirth  dateOfDeath  \
# id
# Q100142069             Frida Eggens          NaN          NaN
# Q100146795       Elizabeth Harrison       1792.0       1834.0
# Q100149196              Russell Cox          NaN          NaN
# Q100152296  Alda Pereira da Fonseca       1882.0          NaN
# Q100156193  Laurence Henry Millener       1914.0       2000.0
#
#            countryOfCitizenshipISO  harvardIndex             bionomia  \
# id
# Q100142069                      SE           NaN                  NaN
# Q100146795                      GB           NaN           Q100146795
# Q100149196                     NaN           NaN  0000-0001-5149-1709
# Q100152296                      BR           NaN                  NaN
# Q100156193                      NZ           NaN           Q100156193
#
#            authorAbbrv                                            aliases  \
# id
# Q100142069      Eggens                                             Eggens
# Q100146795         NaN                     Mrs Arnold Harrison, Mrs A. H.
# Q100149196         NaN                                                NaN
# Q100152296         NaN                                                NaN
# Q100156193         NaN  L. H. Millener, Laurie Henry Millener, Laurie ...
#
#             firstName  lastName      wikiID       first_name last_name  \
# id
# Q100142069      Frida    Eggens  Q100142069            Frida    Eggens
# Q100146795  Elizabeth  Harrison  Q100146795        Elizabeth  Harrison
# Q100149196    Russell       Cox  Q100149196          Russell       Cox
# Q100152296       Alda   Fonseca  Q100152296  Alda Pereira da   Fonseca
# Q100156193   Laurence  Millener  Q100156193   Laurence Henry  Millener
#
#            first_name_initial
# id
# Q100142069                 F.
# Q100146795                 E.
# Q100149196                 R.
# Q100152296           A. P. D.
# Q100156193              L. H.

# %%
indexer = recordlinkage.Index()
indexer.sortedneighbourhood('lastName')# indexer.sortedneighbourhood indexer.full() indexer.block
candidate_links = indexer.index(dfa, dfb)

# %%
compare_cl = recordlinkage.Compare()
# method options: ‘jaro’, ’jarowinkler’, ‘levenshtein’, ‘damerau_levenshtein’, ‘qgram’ or ‘cosine’.
compare_cl.string('firstName', 'firstName', method='damerau_levenshtein', threshold=0.85, label='firstName')
compare_cl.exact('dateOfBirth', 'birthYear', label='dateOfBirth')
# compare_cl.exact('dateOfDeath', 'deathYear', label='dateOfDeath')
# compare_cl.string('authorAbbrv', 'B & P Author Abbrev.', method='damerau_levenshtein', threshold=0.85, label='authorAbbrv')
# compare_cl.string('countryOfCitizenshipISO', 'geographyISO', method='damerau_levenshtein', threshold=0.85, label='geographyISO')
# compare_cl.add(CompareAliases('label', 'Name', threshold=0.85, label='sim'))

features = compare_cl.compute(candidate_links, dfa, dfb)
features.sum(axis=1).value_counts().sort_index(ascending=False)
# Out:
# 2.0     17533
# 1.0     21517
# 0.0    964962
# dtype: int64

# %%
predictions = features[features.sum(axis=1) >= 1]
len(predictions.index.intersection(true_matches))/len(temp)
# Out:
# 0.7268390174714718

# %%
# Threshold-based methods

# Make Predictions based on threshold > 50%
predictions = features[features.sum(axis=1) > 1.5]
print("Threshold-Based: {} matches".format(len(predictions)))

# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(true_matches, predictions, len(features))
# Out:
# Threshold-Based: 17533 matches
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)

# %%
# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))
# Out:
# Confusion Matrix:
#  [[ 14538  16484]
#  [  2995 969995]]
# Precision: 0.8291792619631552
# Recall: 0.4686351621429953
# Accuracy: 0.980598837464094
# F-Measure: 0.5988260735248687

# %%
# Return all the true matched feature as test set
test_matches_index = features.index.intersection(true_matches)
print(test_matches_index)
# Out:
# MultiIndex([('Q100887787', 19901),
#             ('Q117455407', 50431),
#             (  'Q1047867', 48996),
#             ('Q117459360', 14570),
#             ('Q105721668', 25189),
#             ( 'Q33665872', 15901),
#             (   'Q106785', 21404),
#             ( 'Q21505291', 14754),
#             ('Q108403262', 26020),
#             ( 'Q36645320', 71958),
#             ...
#             ( 'Q95101266', 36482),
#             ( 'Q95166173', 11149),
#             ( 'Q95175049',  7562),
#             ( 'Q95394399', 26018),
#             ( 'Q95471212',  4709),
#             (    'Q95772', 15179),
#             (    'Q96384',  5059),
#             (    'Q27684',  1609),
#             (    'Q59570',  2718),
#             (    'Q62938',  1671)],
#            length=27766)

# %%
# Create a training and test set
train, test = train_test_split(features, test_size=0.25, random_state=42) # random_state=42

# Get the true pairs for the test set (Used for Evaluation)
test_matches_index = test.index.intersection(true_matches)

# %%
# Expectation/Conditional Maxisation Classifier

# Initialize the classifier
ecm = recordlinkage.ECMClassifier()
# Train the Model
train_ecm = ecm.fit_predict(train)
# Make Predictions on a test set
predictions = ecm.predict(test)

# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(test_matches_index, predictions, len(test))
# Out:
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)

# %%
# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))
# Out:
# Confusion Matrix:
#  [[  3732   3279]
#  [   769 243223]]
# Precision: 0.8291490779826706
# Recall: 0.5323063756953359
# Accuracy: 0.9838727027167006
# F-Measure: 0.6483669214732453

# %%
# K-means Classifier
# Initialize the classifier
kmeans = recordlinkage.KMeansClassifier()

# Train the Model
train_kmeans = kmeans.learn(train)
# Make Predictions on a test set
predictions = kmeans.predict(test)

# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(test_matches_index, predictions, len(test))
# Out:
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/base.py:899: UserWarning: learn is deprecated, KMeansClassifier.fit_predict instead
#   warnings.warn("learn is deprecated, {}.fit_predict "
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)

# %%
# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))
# Out:
# Confusion Matrix:
#  [[  3732   3279]
#  [   769 243223]]
# Precision: 0.8291490779826706
# Recall: 0.5323063756953359
# Accuracy: 0.9838727027167006
# F-Measure: 0.6483669214732453

# %%
# Create a training and test set
train, test = train_test_split(features, test_size=0.25, random_state=42)

# Get the true pairs for each set
train_matches_index = train.index.intersection(true_matches)
test_matches_index = test.index.intersection(true_matches)

# %%
# Logistic Regression

# Initialize the classifier
logisticRegression = recordlinkage.LogisticRegressionClassifier()

# Train the classifier
logisticRegression.fit_predict(train, train_matches_index)

# Make Predictions on a test set
predictions = logisticRegression.predict(test)

# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(test_matches_index, predictions, len(test))
# Out:
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/base.py:950: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   y.loc[match_index & comparison_vectors.index] = 1
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)

# %%
# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))
# Out:
# Confusion Matrix:
#  [[  3732   3279]
#  [   769 243223]]
# Precision: 0.8291490779826706
# Recall: 0.5323063756953359
# Accuracy: 0.9838727027167006
# F-Measure: 0.6483669214732453

# %%
# Support Vector Machine Classifier

# Initialize the classifier
svm = recordlinkage.SVMClassifier()

# Train the classifier
svm.fit_predict(train, train_matches_index)

# Make Predictions on a test set
predictions = svm.predict(test)

# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(test_matches_index, predictions, len(test))
# Out:
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/base.py:950: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   y.loc[match_index & comparison_vectors.index] = 1
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)

# %%
# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))
# Out:
# Confusion Matrix:
#  [[  3732   3279]
#  [   769 243223]]
# Precision: 0.8291490779826706
# Recall: 0.5323063756953359
# Accuracy: 0.9838727027167006
# F-Measure: 0.6483669214732453

# %%
# Naive Bayes Classifier

# Initialize the classifier
naiveBayes = recordlinkage.NaiveBayesClassifier()

# Train the classifier
naiveBayes.fit_predict(train, train_matches_index)

# Make Predictions on a test set
predictions = naiveBayes.predict(test)

# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(test_matches_index, predictions, len(test))
# Out:
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/base.py:950: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   y.loc[match_index & comparison_vectors.index] = 1
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)

# %%
# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))
# Out:
# Confusion Matrix:
#  [[  3732   3279]
#  [   769 243223]]
# Precision: 0.8291490779826706
# Recall: 0.5323063756953359
# Accuracy: 0.9838727027167006
# F-Measure: 0.6483669214732453

# %%
def find_AinB(df1, col1, df2, col2, threshold):
    newCol = []
    for index1, rowValue1 in df1[col1].iteritems():
        temp = []
        for index2, rowValue2 in df2[col2].iteritems():
            # 
            sim = process.extractOne(str(rowValue1),str(rowValue2).split(','), scorer=fuzz.ratio)
            if sim[-1] >= threshold: temp.append(index2)
        newCol.append(temp)
    return newCol

# %%
temp = find_AinB(a, 'label', b, 'Name', 85)

# %%
from fastparquet import ParquetFile
temp.to_parquet('find_names.parquet', engine='fastparquet',encoding='utf-8')

# %%
# Load feature DataFrames
dfa_feature1 = pd.read_csv('WinH.csv')  
dfb_feature1 = pd.read_csv('HinW.csv')

# %%
dfa_feature1
# Out:
#            wikiID wikiLabel_in_HarvardNameList
# 0      Q100142069                           []
# 1      Q100146795                      [76340]
# 2      Q100149196                           []
# 3      Q100152296                           []
# 4      Q100156193                           []
# ...           ...                          ...
# 71983       Q7324         [34526, 8283, 82867]
# 71984       Q7450                           []
# 71985        Q762                           []
# 71986       Q8619                           []
# 71987        Q926                           []
#
# [71988 rows x 2 columns]

# %%
dfb_feature1
# Out:
#        harvardIndex      havard_in_WikiNameList
# 0             89438               ['Q47125658']
# 1             64680    ['Q102788', 'Q36545989']
# 2             34653  ['Q113588015', 'Q4442569']
# 3             42819                ['Q6158207']
# 4             82862                          []
# ...             ...                         ...
# 76491         72000                          []
# 76492         83026  ['Q21522832', 'Q21522835']
# 76493          7450                          []
# 76494           702                          []
# 76495           180                ['Q5722285']
#
# [76496 rows x 2 columns]

# %%
def add_boolean_column(df, list_column_name, boolean_column_name):
    df[boolean_column_name] = df[list_column_name].apply(lambda x: False if x == "[]" else bool(x))
    return df

# %%
# Merge feature DataFrames into main DataFrames
dfa = pd.merge(dfa, dfa_feature1, on='wikiID')
dfb = pd.merge(dfb, dfb_feature1, on='harvardIndex')

# Set index
dfa.set_index('wikiID', inplace=True)
dfb.set_index('harvardIndex', inplace=True)

# %%
dfa = add_boolean_column(dfa, 'wikiLabel_in_HarvardNameList', 'has_HarvardNameList')
dfa
# Out:
#                               label  dateOfBirth  dateOfDeath  \
# wikiID
# Q100142069             Frida Eggens          NaN          NaN
# Q100146795       Elizabeth Harrison       1792.0       1834.0
# Q100149196              Russell Cox          NaN          NaN
# Q100152296  Alda Pereira da Fonseca       1882.0          NaN
# Q100156193  Laurence Henry Millener       1914.0       2000.0
# ...                             ...          ...          ...
# Q7324                    James Cook       1728.0       1779.0
# Q7450              Asima Chatterjee       1917.0       2006.0
# Q762              Leonardo da Vinci       1452.0       1519.0
# Q8619                Pierre Trudeau       1919.0       2000.0
# Q926                 Roald Amundsen       1872.0       1928.0
#
#            countryOfCitizenshipISO  harvardIndex             bionomia  \
# wikiID
# Q100142069                      SE           NaN                  NaN
# Q100146795                      GB           NaN           Q100146795
# Q100149196                     NaN           NaN  0000-0001-5149-1709
# Q100152296                      BR           NaN                  NaN
# Q100156193                      NZ           NaN           Q100156193
# ...                            ...           ...                  ...
# Q7324                          NaN        8283.0                Q7324
# Q7450                           IN           NaN                  NaN
# Q762                           NaN           NaN                  NaN
# Q8619                           CA           NaN                Q8619
# Q926                            NO           NaN                 Q926
#
#            authorAbbrv                                            aliases  \
# wikiID
# Q100142069      Eggens                                             Eggens
# Q100146795         NaN                     Mrs Arnold Harrison, Mrs A. H.
# Q100149196         NaN                                                NaN
# Q100152296         NaN                                                NaN
# Q100156193         NaN  L. H. Millener, Laurie Henry Millener, Laurie ...
# ...                ...                                                ...
# Q7324             Cook  Captain James Cook, Cook, Captain Cook, J. Coo...
# Q7450              NaN                                Asima Chattopadhyay
# Q762               NaN  Leonardo di ser Piero da Vinci, Leonardo, da V...
# Q8619              NaN  Pierre Elliott Trudeau, Joseph Philippe Pierre...
# Q926               NaN     Roald Engelbregt Gravning Amundsen, R Amundsen
#
#             firstName    lastName       first_name   last_name  \
# wikiID
# Q100142069      Frida      Eggens            Frida      Eggens
# Q100146795  Elizabeth    Harrison        Elizabeth    Harrison
# Q100149196    Russell         Cox          Russell         Cox
# Q100152296       Alda     Fonseca  Alda Pereira da     Fonseca
# Q100156193   Laurence    Millener   Laurence Henry    Millener
# ...               ...         ...              ...         ...
# Q7324           James        Cook            James        Cook
# Q7450           Asima  Chatterjee            Asima  Chatterjee
# Q762         Leonardo       Vinci      Leonardo da       Vinci
# Q8619          Pierre     Trudeau           Pierre     Trudeau
# Q926            Roald    Amundsen            Roald    Amundsen
#
#            first_name_initial wikiLabel_in_HarvardNameList  \
# wikiID
# Q100142069                 F.                           []
# Q100146795                 E.                      [76340]
# Q100149196                 R.                           []
# Q100152296           A. P. D.                           []
# Q100156193              L. H.                           []
# ...                       ...                          ...
# Q7324                      J.         [34526, 8283, 82867]
# Q7450                      A.                           []
# Q762                    L. D.                           []
# Q8619                      P.                           []
# Q926                       R.                           []
#
#             has_HarvardNameList
# wikiID
# Q100142069                False
# Q100146795                 True
# Q100149196                False
# Q100152296                False
# Q100156193                False
# ...                         ...
# Q7324                      True
# Q7450                     False
# Q762                      False
# Q8619                     False
# Q926                      False
#
# [71988 rows x 15 columns]

# %%
dfb = add_boolean_column(dfb, 'havard_in_WikiNameList', 'has_WikiNameList')
dfb
# Out:
#              Standard/Label Name  birthYear  deathYear birthYearIsApprox  \
# harvardIndex
# 89438                 Shin. Sato        NaN        NaN               NaN
# 64680              E. J. Hoffman        NaN        NaN               NaN
# 34653            D. W. Stevenson     1942.0        NaN             False
# 42819         D. Müller-Doblies     1938.0        NaN             False
# 82862                   Boutroux        NaN        NaN               NaN
# ...                          ...        ...        ...               ...
# 72000                      Boeuf        NaN        NaN               NaN
# 83026                     Perold     1928.0        NaN             False
# 7450            Colin C. Stewart     1873.0     1944.0             False
# 702              J. É. Doassans     1852.0     1908.0             False
# 180                C. E. Hubbard     1900.0     1980.0             False
#
#              geographyISO firstName middleName         lastName  \
# harvardIndex
# 89438                  DE    Shinya        NaN             Sato
# 64680                 NaN     Emily         J.          Hoffman
# 34653                  US    Dennis    William        Stevenson
# 42819                  DE  Dietrich        NaN  Müller-Doblies
# 82862                 NaN        A.        NaN         Boutroux
# ...                   ...       ...        ...              ...
# 72000              FR, TN        F.        NaN            Boeuf
# 83026                  ZA     Sarie  Magdalena           Perold
# 7450                   US     Colin         C.          Stewart
# 702                    FR   Jacques      Emile         Doassans
# 180                ES, AU   Charles     Edward          Hubbard
#
#              B & P Author Abbrev.  \
# harvardIndex
# 89438                  Shin. Sato
# 64680               E. J. Hoffman
# 34653                 D. W. Stev.
# 42819           D. Müll.-Doblies
# 82862                    Boutroux
# ...                           ...
# 72000                       Boeuf
# 83026                      Perold
# 7450                          NaN
# 702                        Doass.
# 180                   C. E. Hubb.
#
#                                                            Name first_name  \
# harvardIndex
# 89438                                 Sato, Shinya, Shinya Sato      Shin.
# 64680                       Hoffman, Emily J., Emily J. Hoffman      E. J.
# 34653         Stevenson, Dennis William, Dennis William Stev...      D. W.
# 42819         Müller-Doblies, Dietrich, Dietrich Müller-Do...         D.
# 82862                                 Boutroux, A., A. Boutroux
# ...                                                         ...        ...
# 72000                                       Boeuf, F., F. Boeuf
# 83026           Perold, Sarie Magdalena, Sarie Magdalena Perold
# 7450                       Stewart, Colin C., C. C. Stewart bis   Colin C.
# 702              Doassans, Jacques Emile, Jaques Emile Doassans     J. É.
# 180           Hubbard, Charles Edward, Charles Edward Hubbar...      C. E.
#
#                     last_name first_name_initial      havard_in_WikiNameList  \
# harvardIndex
# 89438                    Sato                 S.               ['Q47125658']
# 64680                 Hoffman              E. J.    ['Q102788', 'Q36545989']
# 34653               Stevenson              D. W.  ['Q113588015', 'Q4442569']
# 42819         Müller-Doblies                 D.                ['Q6158207']
# 82862                Boutroux                                             []
# ...                       ...                ...                         ...
# 72000                   Boeuf                                             []
# 83026                  Perold                     ['Q21522832', 'Q21522835']
# 7450                  Stewart              C. C.                          []
# 702                  Doassans              J. E.                          []
# 180                   Hubbard              C. E.                ['Q5722285']
#
#               has_WikiNameList
# harvardIndex
# 89438                     True
# 64680                     True
# 34653                     True
# 42819                     True
# 82862                    False
# ...                        ...
# 72000                    False
# 83026                     True
# 7450                     False
# 702                      False
# 180                       True
#
# [76496 rows x 15 columns]

# %%
# Define the custom feature function
def custom_boolean_feature(index, dfa, dfb, feature1, feature2):
    result = []
    for a, b in index:
        feature1_value = dfa.loc[a, feature1]
        feature2_value = dfb.loc[b, feature2]
        result.append(feature1_value and feature2_value)
    return pd.Series(result, index=index)

# %%
# Initialize the indexer and create candidate links
indexer = recordlinkage.Index()
indexer.sortedneighbourhood('lastName')  # Can change to other methods like indexer.full(), indexer.block()
candidate_links = indexer.index(dfa, dfb)
# Initialize the comparator
compare_cl = recordlinkage.Compare()

# %%
# Add existing comparison features
compare_cl.string('firstName', 'firstName', method='damerau_levenshtein', threshold=0.85, label='firstName')
compare_cl.exact('dateOfBirth', 'birthYear', label='dateOfBirth')
# Add boolean comparison feature using compare.exact
compare_cl.exact('has_HarvardNameList', 'has_WikiNameList', label='custom_boolean_feature')

# %%
# Create a custom boolean feature
def create_custom_boolean_feature(candidate_links, dfa, dfb, feature1, feature2):
    custom_feature = []
    for a, b in candidate_links:
        feature1_value = dfa.loc[a, feature1]
        feature2_value = dfb.loc[b, feature2]
        result = 1 if feature1_value or feature2_value else 0
        custom_feature.append(result)
    return pd.Series(custom_feature, index=candidate_links)

# %%
# Compute the custom boolean feature
custom_feature_series = create_custom_boolean_feature(candidate_links, dfa, dfb, 'has_HarvardNameList', 'has_WikiNameList')

# Compute the features using recordlinkage
features = compare_cl.compute(candidate_links, dfa, dfb)

# Create a DataFrame from the custom feature series
custom_feature_df = pd.DataFrame(custom_feature_series, columns=['custom_boolean_feature'])

# Merge the custom feature DataFrame with the features DataFrame
features = features.merge(custom_feature_df, left_index=True, right_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [34], in <cell line: 5>()
#       2 custom_feature_series = create_custom_boolean_feature(candidate_links, dfa, dfb, 'has_HarvardNameList', 'has_WikiNameList')
#       4 # Compute the features using recordlinkage
# ----> 5 features = compare_cl.compute(candidate_links, dfa, dfb)
#       7 # Create a DataFrame from the custom feature series
#       8 custom_feature_df = pd.DataFrame(custom_feature_series, columns=['custom_boolean_feature'])
#
# File ~/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/base.py:865, in BaseCompare.compute(self, pairs, x, x_link)
#     862     raise ValueError("expected pandas.DataFrame as third argument")
#     864 if self.n_jobs == 1:
# --> 865     results = self._compute(pairs, x, x_link)
#     866 elif self.n_jobs > 1:
#     867     results = self._compute_parallel(
#     868         pairs, x, x_link, n_jobs=self.n_jobs)
#
# File ~/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/base.py:729, in BaseCompare._compute(self, pairs, x, x_link)
#     723     # else: subset columns and pass tuple of series
#     724     else:
#     725         data2 = tuple(
#     726             [df_b_indexed[lbl] for lbl in listify(feat.labels_right)]
#     727         )
# --> 729     result = feat._compute(data1, data2)
#     730     features.append((result, feat.label))
#     732 features = self._union(features, pairs)
#
# File ~/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/base.py:449, in BaseCompareFeature._compute(self, left_on, right_on)
#     427 def _compute(self, left_on, right_on):
#     428     """Compare the data on the left and right.
#     429
#     430     :meth:`BaseCompareFeature._compute` and
#    (...)
#     447         numpy.ndarray objects.
#     448     """
# --> 449     result = self._compute_vectorized(*tuple(left_on + right_on))
#     451     return result
#
# File ~/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/compare.py:150, in String._compute_vectorized(self, s_left, s_right)
#     146 else:
#     147     raise ValueError("The algorithm '{}' is not known.".format(
#     148         self.method))
# --> 150 c = str_sim_alg(s_left, s_right)
#     152 if self.threshold is not None:
#     153     c = c.where((c < self.threshold) | (pandas.isnull(c)), other=1.0)
#
# File ~/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/algorithms/string.py:82, in damerau_levenshtein_similarity(s1, s2)
#      79         else:
#      80             raise err
# ---> 82 return conc.apply(damerau_levenshtein_apply)
#
# File ~/anaconda3/envs/dgl/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/anaconda3/envs/dgl/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~/anaconda3/envs/dgl/lib/python3.9/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/anaconda3/envs/dgl/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# File ~/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/algorithms/string.py:74, in damerau_levenshtein_similarity.<locals>.damerau_levenshtein_apply(x)
#      71 def damerau_levenshtein_apply(x):
#      73     try:
# ---> 74         return 1 - jellyfish.damerau_levenshtein_distance(x[0], x[1]) \
#      75             / np.max([len(x[0]), len(x[1])])
#      76     except Exception as err:
#      77         if pandas.isnull(x[0]) or pandas.isnull(x[1]):
#
# KeyboardInterrupt:

# %%
# Display the result (features DataFrame)
print(features)
# Out:
#                          firstName  dateOfBirth  custom_boolean_feature
# wikiID     harvardIndex
# Q100142069 12309               0.0            0                       0
#            7349                0.0            0                       1
#            33113               0.0            0                       1
#            82207               0.0            0                       0
# Q100146795 11073               0.0            0                       1
# ...                            ...          ...                     ...
# Q65451     76231               0.0            0                       1
# Q65499     44058               0.0            0                       1
#            6624                0.0            0                       1
# Q6694      48627               0.0            0                       1
# Q762       49464               0.0            0                       0
#
# [1004012 rows x 3 columns]

# %%
features = compare_cl.compute(candidate_links, dfa, dfb)

# %%
# Create a training and test set
train, test = train_test_split(features, test_size=0.25, random_state=42) # random_state=42

print(train)
# Out:
#                          firstName  dateOfBirth  custom_boolean_feature
# wikiID     harvardIndex
# Q13221655  63047               0.0            0                       1
# Q36705638  86181               0.0            0                       1
# Q51278449  49682               0.0            0                       1
# Q88830067  79764               0.0            0                       0
# Q36529743  77298               0.0            0                       1
# ...                            ...          ...                     ...
# Q36537887  40932               0.0            0                       0
# Q88820519  67270               0.0            0                       0
# Q98915388  46079               0.0            0                       0
# Q107574272 63069               0.0            0                       1
# Q94408787  45923               0.0            0                       1
#
# [753009 rows x 3 columns]

# %%
dfa
# Out:
#                               label  dateOfBirth  dateOfDeath  \
# wikiID
# Q100142069             Frida Eggens          NaN          NaN
# Q100146795       Elizabeth Harrison       1792.0       1834.0
# Q100149196              Russell Cox          NaN          NaN
# Q100152296  Alda Pereira da Fonseca       1882.0          NaN
# Q100156193  Laurence Henry Millener       1914.0       2000.0
# ...                             ...          ...          ...
# Q7324                    James Cook       1728.0       1779.0
# Q7450              Asima Chatterjee       1917.0       2006.0
# Q762              Leonardo da Vinci       1452.0       1519.0
# Q8619                Pierre Trudeau       1919.0       2000.0
# Q926                 Roald Amundsen       1872.0       1928.0
#
#            countryOfCitizenshipISO  harvardIndex             bionomia  \
# wikiID
# Q100142069                      SE           NaN                  NaN
# Q100146795                      GB           NaN           Q100146795
# Q100149196                     NaN           NaN  0000-0001-5149-1709
# Q100152296                      BR           NaN                  NaN
# Q100156193                      NZ           NaN           Q100156193
# ...                            ...           ...                  ...
# Q7324                          NaN        8283.0                Q7324
# Q7450                           IN           NaN                  NaN
# Q762                           NaN           NaN                  NaN
# Q8619                           CA           NaN                Q8619
# Q926                            NO           NaN                 Q926
#
#            authorAbbrv                                            aliases  \
# wikiID
# Q100142069      Eggens                                             Eggens
# Q100146795         NaN                     Mrs Arnold Harrison, Mrs A. H.
# Q100149196         NaN                                                NaN
# Q100152296         NaN                                                NaN
# Q100156193         NaN  L. H. Millener, Laurie Henry Millener, Laurie ...
# ...                ...                                                ...
# Q7324             Cook  Captain James Cook, Cook, Captain Cook, J. Coo...
# Q7450              NaN                                Asima Chattopadhyay
# Q762               NaN  Leonardo di ser Piero da Vinci, Leonardo, da V...
# Q8619              NaN  Pierre Elliott Trudeau, Joseph Philippe Pierre...
# Q926               NaN     Roald Engelbregt Gravning Amundsen, R Amundsen
#
#             firstName    lastName       first_name   last_name  \
# wikiID
# Q100142069      Frida      Eggens            Frida      Eggens
# Q100146795  Elizabeth    Harrison        Elizabeth    Harrison
# Q100149196    Russell         Cox          Russell         Cox
# Q100152296       Alda     Fonseca  Alda Pereira da     Fonseca
# Q100156193   Laurence    Millener   Laurence Henry    Millener
# ...               ...         ...              ...         ...
# Q7324           James        Cook            James        Cook
# Q7450           Asima  Chatterjee            Asima  Chatterjee
# Q762         Leonardo       Vinci      Leonardo da       Vinci
# Q8619          Pierre     Trudeau           Pierre     Trudeau
# Q926            Roald    Amundsen            Roald    Amundsen
#
#            first_name_initial wikiLabel_in_HarvardNameList  \
# wikiID
# Q100142069                 F.                           []
# Q100146795                 E.                      [76340]
# Q100149196                 R.                           []
# Q100152296           A. P. D.                           []
# Q100156193              L. H.                           []
# ...                       ...                          ...
# Q7324                      J.         [34526, 8283, 82867]
# Q7450                      A.                           []
# Q762                    L. D.                           []
# Q8619                      P.                           []
# Q926                       R.                           []
#
#             has_HarvardNameList
# wikiID
# Q100142069                False
# Q100146795                 True
# Q100149196                False
# Q100152296                False
# Q100156193                False
# ...                         ...
# Q7324                      True
# Q7450                     False
# Q762                      False
# Q8619                     False
# Q926                      False
#
# [71988 rows x 15 columns]

# %%
# Filter features to include only true matches
true_matches_filtered = true_matches.intersection(features.index)
print(true_matches_filtered)
features_true = features.loc[true_matches_filtered]
print(features_true)
# Out:
# MultiIndex([(   'Q100222', 27614),
#             (  'Q1002345', 17284),
#             ('Q100255559', 18988),
#             ('Q100354624',  3553),
#             ('Q100377900', 88384),
#             (   'Q100411', 23934),
#             ('Q100454982', 50126),
#             (   'Q100523', 78274),
#             ('Q100587885', 29015),
#             ('Q100587966', 14467),
#             ...
#             (    'Q65192', 80079),
#             (    'Q65219', 25324),
#             (     'Q6527', 26300),
#             (    'Q65302',  4297),
#             (    'Q65400',  2192),
#             (    'Q65402', 46610),
#             (    'Q65451',  1041),
#             (    'Q65505', 80335),
#             (     'Q6694',  1813),
#             (     'Q7324',  8283)],
#            names=['wikiID', 'harvardIndex'], length=27766)
#                          firstName  dateOfBirth  custom_boolean_feature
# wikiID     harvardIndex
# Q100222    27614               1.0            1                       1
# Q1002345   17284               1.0            1                       1
# Q100255559 18988               0.0            1                       1
# Q100354624 3553                1.0            1                       0
# Q100377900 88384               1.0            0                       1
# ...                            ...          ...                     ...
# Q65402     46610               1.0            1                       1
# Q65451     1041                1.0            1                       1
# Q65505     80335               1.0            1                       1
# Q6694      1813                0.0            1                       1
# Q7324      8283                1.0            1                       1
#
# [27766 rows x 3 columns]

# %%
train = features_true
print(train)
# Out:
#                          firstName  dateOfBirth  custom_boolean_feature
# wikiID     harvardIndex
# Q100222    27614               1.0            1                       1
# Q1002345   17284               1.0            1                       1
# Q100255559 18988               0.0            1                       1
# Q100354624 3553                1.0            1                       0
# Q100377900 88384               1.0            0                       1
# ...                            ...          ...                     ...
# Q65402     46610               1.0            1                       1
# Q65451     1041                1.0            1                       1
# Q65505     80335               1.0            1                       1
# Q6694      1813                0.0            1                       1
# Q7324      8283                1.0            1                       1
#
# [27766 rows x 3 columns]

# %%
test = features
print(test)
# Out:
#                          firstName  dateOfBirth  custom_boolean_feature
# wikiID     harvardIndex
# Q100142069 12309               0.0            0                       0
#            7349                0.0            0                       1
#            33113               0.0            0                       1
#            82207               0.0            0                       0
# Q100146795 11073               0.0            0                       1
# ...                            ...          ...                     ...
# Q65451     76231               0.0            0                       1
# Q65499     44058               0.0            0                       1
#            6624                0.0            0                       1
# Q6694      48627               0.0            0                       1
# Q762       49464               0.0            0                       0
#
# [1004012 rows x 3 columns]

# %%
# Get the true pairs for the test set (Used for Evaluation)
test_matches_index = test.index.intersection(true_matches)
test_matches_index
# Out:
# MultiIndex([('Q100887787', 19901),
#             ('Q117455407', 50431),
#             (  'Q1047867', 48996),
#             ('Q117459360', 14570),
#             ('Q105721668', 25189),
#             ( 'Q33665872', 15901),
#             (   'Q106785', 21404),
#             ( 'Q21505291', 14754),
#             ('Q108403262', 26020),
#             ( 'Q36645320', 71958),
#             ...
#             ( 'Q95101266', 36482),
#             ( 'Q95166173', 11149),
#             ( 'Q95175049',  7562),
#             ( 'Q95394399', 26018),
#             ( 'Q95471212',  4709),
#             (    'Q95772', 15179),
#             (    'Q96384',  5059),
#             (    'Q27684',  1609),
#             (    'Q59570',  2718),
#             (    'Q62938',  1671)],
#            names=['wikiID', 'harvardIndex'], length=27766)

# %%
# Threshold-based methods

print("Training with threshold-based methods")
# Make Predictions based on threshold > 50%
predictions = features[features.sum(axis=1) > 1.5]
print("Threshold-Based: {} matches".format(len(predictions)))

# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(true_matches, predictions, len(features))

# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))

# Return all the true matched feature as test set
# test_matches_index = features.index.intersection(true_matches)
# print(test_matches_index)


# Expectation/Conditional Maxisation Classifier

print("\nTraining with Expectation/Conditional Maxisation Classifier")
# Initialize the classifier
ecm = recordlinkage.ECMClassifier()
# Train the Model
train_ecm = ecm.fit_predict(train)
# Make Predictions on a test set
predictions = ecm.predict(test)
print("Expectation/Conditional Maxisation: {} matches".format(len(predictions)))

# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(test_matches_index, predictions, len(test))

# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))


# K-means Classifier
# Initialize the classifier
print("\nTraining with K-means Classifier")
kmeans = recordlinkage.KMeansClassifier()

# Train the Model
train_kmeans = kmeans.fit_predict(train)
# Make Predictions on a test set
predictions = kmeans.predict(test)
print("K-means: {} matches".format(len(predictions)))
# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(test_matches_index, predictions, len(test))

# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))
# Out:
# Training with threshold-based methods
# Threshold-Based: 31052 matches
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)
# Confusion Matrix:
#  [[ 20763  10259]
#  [ 10289 962701]]
# Precision: 0.6686525827643952
# Recall: 0.6692992070143768
# Accuracy: 0.9795341091540739
# F-Measure: 0.668975738634533
#
# Training with Expectation/Conditional Maxisation Classifier
# Expectation/Conditional Maxisation: 17533 matches
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)
# Confusion Matrix:
#  [[ 14538  13228]
#  [  2995 973251]]
# Precision: 0.8291792619631552
# Recall: 0.5235900021609162
# Accuracy: 0.983841826591714
# F-Measure: 0.6418684739177465
#
# Training with K-means Classifier
# K-means: 31052 matches
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# Confusion Matrix:
#  [[ 20763   7003]
#  [ 10289 965957]]
# Precision: 0.6686525827643952
# Recall: 0.7477850608658071
# Accuracy: 0.9827770982816938
# F-Measure: 0.7060083647862899
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)

# %%
# Create a training and test set
train, test = train_test_split(features, test_size=0.25, random_state=42)
# Get the true pairs for each set
train_matches_index = train.index.intersection(true_matches)
test_matches_index = test.index.intersection(true_matches)

# Logistic Regression
# Initialize the classifier
print("\nTraining with Logistic Regression")
logisticRegression = recordlinkage.LogisticRegressionClassifier()

# Train the classifier
logisticRegression.fit_predict(train, train_matches_index)

# Make Predictions on a test set
predictions = logisticRegression.predict(test)
print("Logistic Regression: {} matches".format(len(predictions)))

# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(test_matches_index, predictions, len(test))

# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))


# Support Vector Machine Classifier
# Initialize the classifier
print("\nTraining with Support Vector Machine")
svm = recordlinkage.SVMClassifier()

# Train the classifier
svm.fit_predict(train, train_matches_index)

# Make Predictions on a test set
predictions = svm.predict(test)
print("Support Vector Machine: {} matches".format(len(predictions)))

# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(test_matches_index, predictions, len(test))

# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))


# Naive Bayes Classifier
# Initialize the classifier
print("\nTraining with Naive Bayes Classifier")
naiveBayes = recordlinkage.NaiveBayesClassifier()

# Train the classifier
naiveBayes.fit_predict(train, train_matches_index)

# Make Predictions on a test set
predictions = naiveBayes.predict(test)
print("Naive Bayes: {} matches".format(len(predictions)))

# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(test_matches_index, predictions, len(test))

# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))
# Out:
# Training with Logistic Regression
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/base.py:950: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   y.loc[match_index & comparison_vectors.index] = 1
# Logistic Regression: 4501 matches
# Confusion Matrix:
#  [[  3732   3279]
#  [   769 243223]]
# Precision: 0.8291490779826706
# Recall: 0.5323063756953359
# Accuracy: 0.9838727027167006
# F-Measure: 0.6483669214732453
#
# Training with Support Vector Machine
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/base.py:950: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   y.loc[match_index & comparison_vectors.index] = 1
# Support Vector Machine: 4501 matches
# Confusion Matrix:
#  [[  3732   3279]
#  [   769 243223]]
# Precision: 0.8291490779826706
# Recall: 0.5323063756953359
# Accuracy: 0.9838727027167006
# F-Measure: 0.6483669214732453
#
# Training with Naive Bayes Classifier
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/base.py:950: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   y.loc[match_index & comparison_vectors.index] = 1
# Naive Bayes: 4501 matches
# Confusion Matrix:
#  [[  3732   3279]
#  [   769 243223]]
# Precision: 0.8291490779826706
# Recall: 0.5323063756953359
# Accuracy: 0.9838727027167006
# F-Measure: 0.6483669214732453
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)

# %%
# Add existing comparison features
compare_cl.string('firstName', 'firstName', method='damerau_levenshtein', threshold=0.85, label='firstName')
compare_cl.exact('dateOfBirth', 'birthYear', label='dateOfBirth')
compare_cl.exact('dateOfDeath', 'deathYear', label='dateOfDeath')
# Add boolean comparison feature using compare.exact
compare_cl.exact('has_HarvardNameList', 'has_WikiNameList', label='custom_boolean_feature')

features = compare_cl.compute(candidate_links, dfa, dfb)
features.sum(axis=1).value_counts().sort_index(ascending=False)

# Create a training and test set
train, test = train_test_split(features, test_size=0.25, random_state=42) # random_state=42

# Get the true pairs for the test set (Used for Evaluation)
test_matches_index = test.index.intersection(true_matches)

# %%
# Threshold-based methods

print("Training with threshold-based methods")
# Make Predictions based on threshold > 50%
predictions = features[features.sum(axis=1) > 1.5]
print("Threshold-Based: {} matches".format(len(predictions)))

# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(true_matches, predictions, len(features))

# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))

# Return all the true matched feature as test set
# test_matches_index = features.index.intersection(true_matches)
# print(test_matches_index)


# Expectation/Conditional Maxisation Classifier

print("\nTraining with Expectation/Conditional Maxisation Classifier")
# Initialize the classifier
ecm = recordlinkage.ECMClassifier()
# Train the Model
train_ecm = ecm.fit_predict(train)
# Make Predictions on a test set
predictions = ecm.predict(test)
print("Expectation/Conditional Maxisation: {} matches".format(len(predictions)))

# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(test_matches_index, predictions, len(test))

# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))


# K-means Classifier
# Initialize the classifier
print("\nTraining with K-means Classifier")
kmeans = recordlinkage.KMeansClassifier()

# Train the Model
train_kmeans = kmeans.fit_predict(train)
# Make Predictions on a test set
predictions = kmeans.predict(test)
print("K-means: {} matches".format(len(predictions)))
# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(test_matches_index, predictions, len(test))

# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))
# Out:
# Training with threshold-based methods
# Threshold-Based: 32473 matches
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)
# Confusion Matrix:
#  [[ 21631   9391]
#  [ 10842 962148]]
# Precision: 0.6661226249499584
# Recall: 0.6972793501386113
# Accuracy: 0.9798478504240985
# F-Measure: 0.6813449877943145
#
# Training with Expectation/Conditional Maxisation Classifier
# Expectation/Conditional Maxisation: 5114 matches
# Confusion Matrix:
#  [[  4210   2801]
#  [   904 243088]]
# Precision: 0.8232303480641376
# Recall: 0.6004849522179432
# Accuracy: 0.9852392202483635
# F-Measure: 0.6944329896907216
#
# Training with K-means Classifier
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)
# K-means: 5114 matches
# Confusion Matrix:
#  [[  4210   2801]
#  [   904 243088]]
# Precision: 0.8232303480641376
# Recall: 0.6004849522179432
# Accuracy: 0.9852392202483635
# F-Measure: 0.6944329896907216
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)

# %%
# Create a training and test set
train, test = train_test_split(features, test_size=0.25, random_state=42)
# Get the true pairs for each set
train_matches_index = train.index.intersection(true_matches)
test_matches_index = test.index.intersection(true_matches)

# Logistic Regression
# Initialize the classifier
print("\nTraining with Logistic Regression")
logisticRegression = recordlinkage.LogisticRegressionClassifier()

# Train the classifier
logisticRegression.fit_predict(train, train_matches_index)

# Make Predictions on a test set
predictions = logisticRegression.predict(test)
print("Logistic Regression: {} matches".format(len(predictions)))

# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(test_matches_index, predictions, len(test))

# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))


# Support Vector Machine Classifier
# Initialize the classifier
print("\nTraining with Support Vector Machine")
svm = recordlinkage.SVMClassifier()

# Train the classifier
svm.fit_predict(train, train_matches_index)

# Make Predictions on a test set
predictions = svm.predict(test)
print("Support Vector Machine: {} matches".format(len(predictions)))

# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(test_matches_index, predictions, len(test))

# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))


# Naive Bayes Classifier
# Initialize the classifier
print("\nTraining with Naive Bayes Classifier")
naiveBayes = recordlinkage.NaiveBayesClassifier()

# Train the classifier
naiveBayes.fit_predict(train, train_matches_index)

# Make Predictions on a test set
predictions = naiveBayes.predict(test)
print("Naive Bayes: {} matches".format(len(predictions)))

# Get the confusion matrix. This is just the table with the numbers of True/False Postives and True/False Negatives.
confusion_matrix = recordlinkage.confusion_matrix(test_matches_index, predictions, len(test))

# Print Metrics
print("Confusion Matrix:\n", confusion_matrix)
print("Precision:", recordlinkage.precision(confusion_matrix))
print("Recall:", recordlinkage.recall(confusion_matrix))
print("Accuracy:", recordlinkage.accuracy(confusion_matrix))
print("F-Measure:", recordlinkage.fscore(confusion_matrix))
# Out:
# Training with Logistic Regression
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/base.py:950: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   y.loc[match_index & comparison_vectors.index] = 1
# Logistic Regression: 4678 matches
# Confusion Matrix:
#  [[  3871   3140]
#  [   807 243185]]
# Precision: 0.8274903805044891
# Recall: 0.5521323634288975
# Accuracy: 0.9842750883455577
# F-Measure: 0.6623321071092481
#
# Training with Support Vector Machine
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/base.py:950: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   y.loc[match_index & comparison_vectors.index] = 1
# Support Vector Machine: 5114 matches
# Confusion Matrix:
#  [[  4210   2801]
#  [   904 243088]]
# Precision: 0.8232303480641376
# Recall: 0.6004849522179432
# Accuracy: 0.9852392202483635
# F-Measure: 0.6944329896907216
#
# Training with Naive Bayes Classifier
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/base.py:950: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   y.loc[match_index & comparison_vectors.index] = 1
# Naive Bayes: 5114 matches
# Confusion Matrix:
#  [[  4210   2801]
#  [   904 243088]]
# Precision: 0.8232303480641376
# Recall: 0.6004849522179432
# Accuracy: 0.9852392202483635
# F-Measure: 0.6944329896907216
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:147: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   return len(links_true & links_pred)
# /Users/mbax9qg2/anaconda3/envs/dgl/lib/python3.9/site-packages/recordlinkage/measures.py:179: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   return int(total) - len(links_true | links_pred)

# %%
matches = predictions.to_frame(index=False).reset_index()
# Ensure the matches DataFrame is properly structured
matches = matches[['wikiID', 'harvardIndex']]

# Convert the matches DataFrame to a MultiIndex
matches['harvardIndex'] = matches['harvardIndex'].astype(int)
matches_index = pd.MultiIndex.from_frame(matches)
print(matches_index)

# Find the intersection
intersection = matches_index.intersection(true_matches)
# print(true_matches)
print(intersection)

# Find the non-intersection pairs
non_intersection = matches_index.difference(true_matches)
print(non_intersection)

# Create a DataFrame from the intersection
# intersection_df = pd.DataFrame(list(intersection), columns=['wikiID', 'harvardIndex'])

# Display the intersection DataFrame
# print(intersection_df)
# Out:
# MultiIndex([('Q21607397', 76979),
#             ( 'Q2738600',  1143),
#             ('Q21607469', 82514),
#             ('Q21607087', 79206),
#             ( 'Q4278489', 14625),
#             ('Q21520095', 23364),
#             ('Q21340735',  7852),
#             ('Q21522632', 38471),
#             ('Q21505412', 70911),
#             ( 'Q4814932', 67037),
#             ...
#             ('Q21512488', 74732),
#             ('Q21519722', 70659),
#             ('Q21608672', 16236),
#             ('Q21509717', 63975),
#             ('Q21522788', 79656),
#             ( 'Q5408677', 70352),
#             ('Q21338085', 41688),
#             ('Q17279919', 44843),
#             ('Q21515836', 42125),
#             ('Q21609897', 48371)],
#            names=['wikiID', 'harvardIndex'], length=4501)
# MultiIndex([('Q21607397', 76979),
#             ('Q21607469', 82514),
#             ('Q21607087', 79206),
#             ( 'Q4278489', 14625),
#             ('Q21520095', 23364),
#             ('Q21340735',  7852),
#             ('Q21522632', 38471),
#             ('Q21505412', 70911),
#             ( 'Q4814932', 67037),
#             ('Q21394054', 64858),
#             ...
#             ('Q21512488', 74732),
#             ('Q21519722', 70659),
#             ('Q21608672', 16236),
#             ('Q21509717', 63975),
#             ('Q21522788', 79656),
#             ( 'Q5408677', 70352),
#             ('Q21338085', 41688),
#             ('Q17279919', 44843),
#             ('Q21515836', 42125),
#             ('Q21609897', 48371)],
#            names=['wikiID', 'harvardIndex'], length=3732)
# MultiIndex([(  'Q1025362', 38484),
#             ( 'Q10304543', 27401),
#             ( 'Q10308271', 41312),
#             (  'Q1036746', 48927),
#             ( 'Q10392118', 68041),
#             (  'Q1040980', 36830),
#             (  'Q1065059',  2944),
#             ('Q106561642', 24253),
#             ('Q106865213', 35379),
#             ('Q106888951', 73381),
#             ...
#             ( 'Q95305104', 90304),
#             ( 'Q95376685', 35285),
#             ( 'Q95689401', 32239),
#             ( 'Q95850724', 37663),
#             ( 'Q95977163', 40095),
#             ( 'Q96023274', 35024),
#             (  'Q9638330', 64274),
#             (   'Q978054', 31075),
#             ( 'Q98834493', 40324),
#             ( 'Q98848124', 38587)],
#            names=['wikiID', 'harvardIndex'], length=769)

# %%
# Create a DataFrame from the non-intersection pairs
non_intersection_df = pd.DataFrame(list(non_intersection), columns=['wikiID', 'harvardIndex'])
# Convert matches columns to string to ensure consistency
non_intersection_df['wikiID'] = non_intersection_df['wikiID'].astype(str)
non_intersection_df['harvardIndex'] = non_intersection_df['harvardIndex'].astype(str)

# %%
notfound_matched_dfa = dfa.loc[non_intersection_df['wikiID']].reset_index()
notfound_matched_dfb = dfb.loc[non_intersection_df['harvardIndex']].reset_index()
# Combine the matched DataFrames side by side
combined_notfound_matches = pd.concat([notfound_matched_dfa, notfound_matched_dfb], axis=1)

# Optionally add a label to identify matched rows
combined_notfound_matches['matched'] = True

# %%
combined_notfound_matches
# Out:
#            wikiID                                   label  dateOfBirth  \
# 0      Q100146795                      Elizabeth Harrison       1792.0
# 1      Q100587966                          A. W. Anderson          NaN
# 2      Q100587966                          A. W. Anderson          NaN
# 3      Q100709237                    Hein Hidde Zeijlstra       1881.0
# 4      Q100869469                           Ivar Holmgren       1889.0
# ...           ...                                     ...          ...
# 10284      Q99616  Carl Heinrich 'Schultzenstein' Schultz       1798.0
# 10285   Q99662370                      Henry Tuke Mennell       1835.0
# 10286      Q99686                               Kurt Harz       1915.0
# 10287   Q99736256                           Rudolf Wagner       1872.0
# 10288   Q99875747                             Karl Hedbom       1859.0
#
#        dateOfDeath countryOfCitizenshipISO harvardIndex    bionomia  \
# 0           1834.0                      GB          NaN  Q100146795
# 1              NaN                     NaN        14467         NaN
# 2              NaN                     NaN        14467         NaN
# 3           1961.0                     NaN          NaN         NaN
# 4           1975.0                      SE          NaN         NaN
# ...            ...                     ...          ...         ...
# 10284       1871.0                      DE      60868.0         NaN
# 10285       1923.0                      GB          NaN   Q99662370
# 10286       1996.0                      DE          NaN      Q99686
# 10287       1938.0                      DE       1427.0         NaN
# 10288       1924.0                      SE          NaN   Q99875747
#
#         authorAbbrv                         aliases  firstName  ... birthYear  \
# 0               NaN  Mrs Arnold Harrison, Mrs A. H.  Elizabeth  ...       NaN
# 1               NaN                             NaN         A.  ...       NaN
# 2               NaN                             NaN         A.  ...       NaN
# 3               NaN                             NaN       Hein  ...    1881.0
# 4               NaN                             NaN       Ivar  ...    1889.0
# ...             ...                             ...        ...  ...       ...
# 10284  Schultz Sch.                    Schultz Sch.       Carl  ...    1765.0
# 10285           NaN                   H. T. Mennell      Henry  ...    1835.0
# 10286           NaN                             NaN       Kurt  ...    1858.0
# 10287      R.Wagner                             NaN     Rudolf  ...    1842.0
# 10288           NaN               Karl Johan Hedbom       Karl  ...    1859.0
#
#       deathYear birthYearIsApprox  geographyISO  firstName middleName  \
# 0           NaN               NaN           NaN  Elizabeth        NaN
# 1           NaN               NaN            DK         A.       Edm.
# 2           NaN               NaN            US         A.         L.
# 3           NaN             False            ID       Hein      Hidde
# 4           NaN             False            EC       Ivar     Albert
# ...         ...               ...           ...        ...        ...
# 10284    1837.0             False            DE       Carl  Friedrich
# 10285    1923.0             False           NaN      Henry       Tuke
# 10286    1939.0             False            DE       Kurt        NaN
# 10287    1913.0             False            DE     Rudolf     Eduard
# 10288       NaN             False            NO       Karl      Johan
#
#         lastName B & P Author Abbrev.  \
# 0         Harris            E. Harris
# 1       Andersen                  NaN
# 2       Anderson                  NaN
# 3      Zeijlstra                  NaN
# 4       Holmgren                  NaN
# ...          ...                  ...
# 10284    Schultz              Schultz
# 10285    Mennell                  NaN
# 10286       Harz               K.Harz
# 10287     Wagner         R. E. Wagner
# 10288     Hedbom                  NaN
#
#                                                   Name matched
# 0                  Harris, Elizabeth, Elizabeth Harris    True
# 1                                    Andersen, A. Edm.    True
# 2                                      Anderson, A. L.    True
# 3                                Zeijlstra, Hein Hidde    True
# 4                                Holmgren, Ivar Albert    True
# ...                                                ...     ...
# 10284  Schultz, Carl Friedrich, Carl Friedrich Schultz    True
# 10285                              Mennell, Henry Tuke    True
# 10286                            Harz, Kurt, Kurt Harz    True
# 10287      Wagner, Rudolf Eduard, Rudolf Eduard Wagner    True
# 10288                               Hedbom, Karl Johan    True
#
# [10289 rows x 23 columns]

# %%
dfa = a.copy()
dfb = b.copy()

# Set indices
dfa.set_index('wikiID', inplace=True)
dfb.set_index('harvardIndex', inplace=True)

# Convert matches columns to string to ensure consistency
matches['wikiID'] = matches['wikiID'].astype(str)
matches['harvardIndex'] = matches['harvardIndex'].astype(str)
dfa.index = dfa.index.astype(str)
dfb.index = dfb.index.astype(str)

# Ensure the matches DataFrame is properly structured
matches = matches[['wikiID', 'harvardIndex']]

# Merge the matches with the original data
matched_dfa = dfa.loc[matches['wikiID']].reset_index()
matched_dfb = dfb.loc[matches['harvardIndex']].reset_index()

# Combine the matched DataFrames side by side
combined_matches = pd.concat([matched_dfa, matched_dfb], axis=1)

# Optionally add a label to identify matched rows
combined_matches['matched'] = True

# %%
combined_matches
# Out:
#            wikiID                               label  dateOfBirth  \
# 0        Q8012324             William Higgins Coleman       1812.0
# 1        Q8012324             William Higgins Coleman       1812.0
# 2      Q100887787                          A.J. Ultee       1878.0
# 3      Q117455407                     Rosa Lydia Otto       1909.0
# 4      Q117600078                        Martin Jones       1897.0
# ...           ...                                 ...          ...
# 31047   Q97495995                      Józef Liboszyc       1783.0
# 31048      Q98266                      Willy Cullmann       1905.0
# 31049      Q57763                   Ludwig Leichhardt       1813.0
# 31050      Q59570               Theodor Koch-Grunberg       1872.0
# 31051      Q62938  Joseph zu Salm-Reifferscheidt-Dyck       1773.0
#
#        dateOfDeath countryOfCitizenshipISO harvardIndex bionomia authorAbbrv  \
# 0           1863.0                     NaN          481      NaN     Coleman
# 1           1863.0                     NaN          481      NaN     Coleman
# 2           1964.0                      NL        19901      NaN         NaN
# 3              NaN                     NaN        50431      NaN         NaN
# 4           1979.0                     NaN          NaN      NaN         NaN
# ...            ...                     ...          ...      ...         ...
# 31047       1832.0                     NaN          NaN      NaN         NaN
# 31048       1992.0                      DE          NaN      NaN    Cullmann
# 31049       1848.0                      AU      70138.0   Q57763     Leichh.
# 31050       1924.0                      DE       2718.0      NaN         NaN
# 31051       1861.0                      FR       1671.0      NaN   Salm-Dyck
#
#                                                  aliases  firstName  ...  \
# 0                                                Coleman    William  ...
# 1                                                Coleman    William  ...
# 2                                Arnoldus Johannes Ultee       A.J.  ...
# 3           Rosa Lydia Otto-Surbeck, Mrs L. Otto-Surbeck       Rosa  ...
# 4                                        Martin G. Jones     Martin  ...
# ...                                                  ...        ...  ...
# 31047                                                NaN      Józef  ...
# 31048                      W. Cullmann, Wilhelm Cullmann      Willy  ...
# 31049  Leichh., Friedrich Wilhelm Ludwig Leichhardt, ...     Ludwig  ...
# 31050                              Theodor Koch-Grünberg    Theodor  ...
# 31051      Salm-Dyck, Joseph de Salm-Reifferscheidt-Dyck     Joseph  ...
#
#       birthYear deathYear birthYearIsApprox  geographyISO  firstName  \
# 0        1811.0    1899.0             False            NZ    William
# 1        1811.0    1899.0             False            NZ    William
# 2        1878.0    1963.0             False            ID   Arnoldus
# 3        1909.0       NaN             False            ID       Rosa
# 4        1897.0    1944.0             False            ID     Willem
# ...         ...       ...               ...           ...        ...
# 31047    1783.0    1824.0             False            RU     Joseph
# 31048    1905.0    1992.0             False            US      Willy
# 31049    1813.0    1848.0             False            AU     Ludwig
# 31050    1872.0    1924.0             False    CO, VE, BR  Christian
# 31051    1773.0    1861.0             False        DE, ZA     Joseph
#
#                                       middleName                 lastName  \
# 0                                            NaN                  Colenso
# 1                                            NaN                  Colenso
# 2                                       Johannes                   Ultée
# 3                                          Lydia             Otto-Surbeck
# 4                                             de                     Jong
# ...                                          ...                      ...
# 31047                                        NaN               Liboschitz
# 31048                                        NaN                  Cullman
# 31049                                        NaN                Leichardt
# 31050                                    Theodor                     Koch
# 31051  Franz Maria Anton Hubert Ignatz Fürst zu  Salm-Reifferscheid-Dyck
#
#       B & P Author Abbrev.                                               Name  \
# 0                      NaN                              Colenso, Rev. William
# 1                  Colenso           Colenso, (John) William, William Colenso
# 2                      NaN                          Ultée, Arnoldus Johannes
# 3                      NaN      Otto-Surbeck, Rosa Lydia, Otto-Surbeck, R. L.
# 4                      NaN                                    Jong, Willem de
# ...                    ...                                                ...
# 31047             Libosch.              Liboschitz, Joseph, Joseph Liboschitz
# 31048              Cullman                     Cullman, Willy, Willy Cullmann
# 31049                  NaN              Leichardt, (Friedrich Wilhelm) Ludwig
# 31050                  NaN  Koch, Christian Theodor, Koch, Christian Theod...
# 31051            Salm-Dyck  Salm-Reifferscheid-Dyck, Joseph Franz Maria An...
#
#       matched
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ...       ...
# 31047    True
# 31048    True
# 31049    True
# 31050    True
# 31051    True
#
# [31052 rows x 23 columns]

# %%
W_match_H = pd.concat([combined_matches, combined_notfound_matches], axis=1)

# %%
W_match_H
# Out:
#            wikiID                               label  dateOfBirth  \
# 0        Q8012324             William Higgins Coleman       1812.0
# 1        Q8012324             William Higgins Coleman       1812.0
# 2      Q100887787                          A.J. Ultee       1878.0
# 3      Q117455407                     Rosa Lydia Otto       1909.0
# 4      Q117600078                        Martin Jones       1897.0
# ...           ...                                 ...          ...
# 31047   Q97495995                      Józef Liboszyc       1783.0
# 31048      Q98266                      Willy Cullmann       1905.0
# 31049      Q57763                   Ludwig Leichhardt       1813.0
# 31050      Q59570               Theodor Koch-Grunberg       1872.0
# 31051      Q62938  Joseph zu Salm-Reifferscheidt-Dyck       1773.0
#
#        dateOfDeath countryOfCitizenshipISO harvardIndex bionomia authorAbbrv  \
# 0           1863.0                     NaN          481      NaN     Coleman
# 1           1863.0                     NaN          481      NaN     Coleman
# 2           1964.0                      NL        19901      NaN         NaN
# 3              NaN                     NaN        50431      NaN         NaN
# 4           1979.0                     NaN          NaN      NaN         NaN
# ...            ...                     ...          ...      ...         ...
# 31047       1832.0                     NaN          NaN      NaN         NaN
# 31048       1992.0                      DE          NaN      NaN    Cullmann
# 31049       1848.0                      AU      70138.0   Q57763     Leichh.
# 31050       1924.0                      DE       2718.0      NaN         NaN
# 31051       1861.0                      FR       1671.0      NaN   Salm-Dyck
#
#                                                  aliases  firstName  ...  \
# 0                                                Coleman    William  ...
# 1                                                Coleman    William  ...
# 2                                Arnoldus Johannes Ultee       A.J.  ...
# 3           Rosa Lydia Otto-Surbeck, Mrs L. Otto-Surbeck       Rosa  ...
# 4                                        Martin G. Jones     Martin  ...
# ...                                                  ...        ...  ...
# 31047                                                NaN      Józef  ...
# 31048                      W. Cullmann, Wilhelm Cullmann      Willy  ...
# 31049  Leichh., Friedrich Wilhelm Ludwig Leichhardt, ...     Ludwig  ...
# 31050                              Theodor Koch-Grünberg    Theodor  ...
# 31051      Salm-Dyck, Joseph de Salm-Reifferscheidt-Dyck     Joseph  ...
#
#       birthYear deathYear birthYearIsApprox  geographyISO  firstName  \
# 0           NaN       NaN               NaN           NaN  Elizabeth
# 1           NaN       NaN               NaN            DK         A.
# 2           NaN       NaN               NaN            US         A.
# 3        1881.0       NaN             False            ID       Hein
# 4        1889.0       NaN             False            EC       Ivar
# ...         ...       ...               ...           ...        ...
# 31047       NaN       NaN               NaN           NaN        NaN
# 31048       NaN       NaN               NaN           NaN        NaN
# 31049       NaN       NaN               NaN           NaN        NaN
# 31050       NaN       NaN               NaN           NaN        NaN
# 31051       NaN       NaN               NaN           NaN        NaN
#
#       middleName   lastName B & P Author Abbrev.  \
# 0            NaN     Harris            E. Harris
# 1           Edm.   Andersen                  NaN
# 2             L.   Anderson                  NaN
# 3          Hidde  Zeijlstra                  NaN
# 4         Albert   Holmgren                  NaN
# ...          ...        ...                  ...
# 31047        NaN        NaN                  NaN
# 31048        NaN        NaN                  NaN
# 31049        NaN        NaN                  NaN
# 31050        NaN        NaN                  NaN
# 31051        NaN        NaN                  NaN
#
#                                       Name matched
# 0      Harris, Elizabeth, Elizabeth Harris    True
# 1                        Andersen, A. Edm.    True
# 2                          Anderson, A. L.    True
# 3                    Zeijlstra, Hein Hidde    True
# 4                    Holmgren, Ivar Albert    True
# ...                                    ...     ...
# 31047                                  NaN     NaN
# 31048                                  NaN     NaN
# 31049                                  NaN     NaN
# 31050                                  NaN     NaN
# 31051                                  NaN     NaN
#
# [31052 rows x 46 columns]

# %%
# If needed, add unmatched rows with a 'matched' flag as False
unmatched_dfa = dfa[~dfa.index.isin(matches['harvardIndex'])].reset_index()
unmatched_dfa['matched'] = False

unmatched_dfb = dfb[~dfb.index.isin(matches['harvardIndex'])].reset_index()
unmatched_dfb['matched'] = False

# %%
b
# Out:
#       Standard/Label Name  birthYear  deathYear birthYearIsApprox  \
# id
# 89438          Shin. Sato        NaN        NaN               NaN
# 64680       E. J. Hoffman        NaN        NaN               NaN
# 34653     D. W. Stevenson     1942.0        NaN             False
# 42819  D. Müller-Doblies     1938.0        NaN             False
# 82862            Boutroux        NaN        NaN               NaN
# ...                   ...        ...        ...               ...
# 72000               Boeuf        NaN        NaN               NaN
# 83026              Perold     1928.0        NaN             False
# 7450     Colin C. Stewart     1873.0     1944.0             False
# 702       J. É. Doassans     1852.0     1908.0             False
# 180         C. E. Hubbard     1900.0     1980.0             False
#
#       geographyISO firstName middleName         lastName B & P Author Abbrev.  \
# id
# 89438           DE    Shinya        NaN             Sato           Shin. Sato
# 64680          NaN     Emily         J.          Hoffman        E. J. Hoffman
# 34653           US    Dennis    William        Stevenson          D. W. Stev.
# 42819           DE  Dietrich        NaN  Müller-Doblies    D. Müll.-Doblies
# 82862          NaN        A.        NaN         Boutroux             Boutroux
# ...            ...       ...        ...              ...                  ...
# 72000       FR, TN        F.        NaN            Boeuf                Boeuf
# 83026           ZA     Sarie  Magdalena           Perold               Perold
# 7450            US     Colin         C.          Stewart                  NaN
# 702             FR   Jacques      Emile         Doassans               Doass.
# 180         ES, AU   Charles     Edward          Hubbard          C. E. Hubb.
#
#                                                     Name  harvardIndex
# id
# 89438                          Sato, Shinya, Shinya Sato         89438
# 64680                Hoffman, Emily J., Emily J. Hoffman         64680
# 34653  Stevenson, Dennis William, Dennis William Stev...         34653
# 42819  Müller-Doblies, Dietrich, Dietrich Müller-Do...         42819
# 82862                          Boutroux, A., A. Boutroux         82862
# ...                                                  ...           ...
# 72000                                Boeuf, F., F. Boeuf         72000
# 83026    Perold, Sarie Magdalena, Sarie Magdalena Perold         83026
# 7450                Stewart, Colin C., C. C. Stewart bis          7450
# 702       Doassans, Jacques Emile, Jaques Emile Doassans           702
# 180    Hubbard, Charles Edward, Charles Edward Hubbar...           180
#
# [76496 rows x 11 columns]

# %%
# Find out the True Matches of dataframe A and dataframe B
a['harvardIndex'] = pd.to_numeric(a['harvardIndex'],errors='coerce') 
temp = pd.merge(a, b, how='inner', on=None, left_on='harvardIndex', right_on='harvardIndex',
                  left_index=False, right_index=False, sort=False,
                  suffixes=('_wiki', '_harvard'), copy=False, indicator=False)

# print(temp.columns.to_list())
# temp.head()

true_matches = define_true_pairs(temp['wikiID'],temp['harvardIndex'].astype(int),'wikiIndex','harvardIndex')
# print(true_matches)
print('There is '+ str(len(true_matches)) +' HarvardIndex records in Wikidata that can find a match, which is ' + str(len(true_matches)/len(a)*100) +'%')
print('There is '+ str(len(true_matches)) +' HarvardIndex records can be found in Wikidata, which is ' + str(len(true_matches)/len(b)*100) +'%')
